# %% [markdown]
# <a href="https://colab.research.google.com/github/noufanelachola/code_to_language/blob/main/notebooks/CodeToEnglish_Translator_Main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# AI-Powered Code-to-English Translator for Healthcare Software
# Main Notebook - CodeBERT + Gradio
# Name: Noufan Elachola | Roll No: 69 | Class: s6 CS2

# %%
# !pip install -q transformers torch gradio

# %%
from transformers import AutoTokenizer, AutoModel

# %%
import torch

# %%
model_name = "microsoft/codebert-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/498 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]

# %%
AutoModel.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
# Out:
# ...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
sample_code = """
def calculate_bmi(weight,height):
  bmi = weight/height**2
  if bmi > 25:
    return "overweight"
  else :
    return "normal"
"""

# %%
inputs = tokenizer(sample_code, return_tensors="pt")

with torch.no_grad():
    outputs = model(**inputs)

print("Input IDs shape : ",inputs["input_ids"].shape)
print("Last hidden state shape : ",outputs.last_hidden_state.shape)
# Out:
# Input IDs shape :  torch.Size([1, 53])
# Last hidden state shape :  torch.Size([1, 53, 768])

# %%
import json
from pathlib import Path

# Put the exact name you saw from os.listdir("notebooks")
nb_path = Path("notebooks/CodeToEnglish_Translator_Main.ipynb")  # <-- change if needed

with nb_path.open("r", encoding="utf-8") as f:
    nb = json.load(f)

meta = nb.get("metadata", {})
if "widgets" in meta:
    print("Found 'metadata.widgets' – removing it to fix GitHub rendering.")
    del meta["widgets"]
    nb["metadata"] = meta
else:
    print("No 'metadata.widgets' found. Nothing to remove.")

clean_path = Path("notebooks/CodeToEnglish_Translator_Main_clean.ipynb")  # or any *_clean name
with clean_path.open("w", encoding="utf-8") as f:
    json.dump(nb, f, indent=2)

print("Saved cleaned notebook as:", clean_path)
# Out:
# Found 'metadata.widgets' – removing it to fix GitHub rendering.
# Saved cleaned notebook as: notebooks/CodeToEnglish_Translator_Main_clean.ipynb
